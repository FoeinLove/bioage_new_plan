# %%
import pandas as pd
from pycaret.regression import *

df = pd.read_csv('reduced_merge.csv')
m = load_model('extended_range_model')
predict_model(m,df)
# Out:
# Transformation Pipeline and Model Successfully Loaded
#                 ID  GENDER   AGE  UREA     UA  APO_A   LP_A  HS_CRP    CRE  \
# 0     211101003002       2  58.0  7.24  452.0   1.95  344.0     1.0   83.0
# 1     211101010001       2  69.0  6.06  200.0   1.79  400.0     1.0   71.0
# 2     211101012001       1  61.0  7.31  339.0   1.35   10.0     1.0  100.0
# 3     211101012002       2  56.0  5.92  366.0   1.63  215.0     3.0   75.0
# 4     211101013002       2  66.0  5.53  279.0   2.39   77.0     2.0   70.0
# ...            ...     ...   ...   ...    ...    ...    ...     ...    ...
# 8447  522404101002       2  30.0  6.33  296.0   1.17  560.0     1.0   81.0
# 8448  522404102002       2  30.0  6.96  265.0   0.97   80.0     0.0   92.0
# 8449  522404121001       1  38.0  5.47  460.0   1.07    9.0     1.0   92.0
# 8450  522404121002       2  36.0  4.63  236.0   0.96   30.0     0.0   80.0
# 8451  522404122001       1  34.0  5.09  306.0   1.12  202.0     1.0   98.0
#
# ...
